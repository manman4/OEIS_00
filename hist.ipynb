# %% [markdown]
# ## sequence_list.csvの作成

# %%
import subprocess

result = subprocess.run(["ruby", "create_list.rb"], capture_output=True, text=True)
print(result.stdout)  # Rubyスクリプトの標準出力を表示

# エラー出力を表示
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT:
# STDERR:

# %%
import pandas as pd

data_file = 'sequence_list.csv'

# %% [markdown]
# # フォルダ毎の数列の数

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] // 1000
df
# Out:
#       seq_no
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2142      99
# 2143      99
# 2144      99
# 2145      99
# 2146      99
#
# [2147 rows x 1 columns]

# %%
# show_rangeの開始に注意
show_range = list(range(-1, 99+1))
df.plot.hist(bins=show_range)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# ヒストグラムの度数分布表を作成
hist = pd.cut(df['seq_no'], bins=show_range).value_counts().sort_index()

# 度数分布表を表示（ただし、度数が0は除く）
print('度数分布表')

cnt = 0
for i in hist.index:
    cnt += 1
    if i.right % 10 == 0:
        print()
    print(f'{i.right} : {hist[i]}', end=', ')

print()
print(f'合計 : {cnt}')
# Out:
# 度数分布表
#
# 0 : 51, 1 : 38, 2 : 35, 3 : 22, 4 : 69, 5 : 27, 6 : 22, 7 : 44, 8 : 51, 9 : 11,
# 10 : 28, 11 : 3, 12 : 4, 13 : 15, 14 : 16, 15 : 66, 16 : 10, 17 : 9, 18 : 37, 19 : 11,
# 20 : 6, 21 : 1, 22 : 108, 23 : 43, 24 : 10, 25 : 16, 26 : 14, 27 : 44, 28 : 29, 29 : 30,
# 30 : 54, 31 : 9, 32 : 12, 33 : 99, 34 : 17, 35 : 107, 36 : 17, 37 : 11, 38 : 14, 39 : 19,
# 40 : 2, 41 : 0, 42 : 0, 43 : 2, 44 : 0, 45 : 24, 46 : 15, 47 : 7, 48 : 8, 49 : 25,
# 50 : 21, 51 : 18, 52 : 31, 53 : 25, 54 : 29, 55 : 39, 56 : 14, 57 : 16, 58 : 30, 59 : 18,
# 60 : 16, 61 : 35, 62 : 33, 63 : 7, 64 : 16, 65 : 7, 66 : 21, 67 : 5, 68 : 11, 69 : 13,
# 70 : 19, 71 : 12, 72 : 17, 73 : 15, 74 : 12, 75 : 10, 76 : 9, 77 : 10, 78 : 20, 79 : 15,
# 80 : 13, 81 : 11, 82 : 18, 83 : 19, 84 : 13, 85 : 9, 86 : 6, 87 : 12, 88 : 12, 89 : 13,
# 90 : 15, 91 : 21, 92 : 20, 93 : 7, 94 : 12, 95 : 3, 96 : 16, 97 : 20, 98 : 26, 99 : 25,
# 合計 : 100

# %% [markdown]
# # 偏り

# %%
df = pd.read_csv(data_file)
df.columns = ['no', 'seq_no']
df = df[['seq_no']]
df['seq_no'] = df['seq_no'] % 100
df
# Out:
#       seq_no
# 0          5
# 1         10
# 2         11
# 3         12
# 4         13
# ...      ...
# 2142      27
# 2143      29
# 2144      31
# 2145      57
# 2146      79
#
# [2147 rows x 1 columns]

# %%
df.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>
